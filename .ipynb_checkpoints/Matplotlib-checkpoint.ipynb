# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.getcwd()
# Out:
# '/home/luiz/GitHub/data_science'

# %%
data = pd.read_csv(r'titanic/train.csv')

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.columns = ['idpassageiro', 'sobreviveu', 'classe', 'nome', 'sexo', 'idade', 'irmaosconjuge',
       'paisfilhos', 'bilhete', 'tarifa', 'cabine', 'embarque']

# %%
data.head()
# Out:
#    idpassageiro  sobreviveu  classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 nome    sexo  idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    irmaosconjuge  paisfilhos           bilhete   tarifa cabine embarque
# 0              1           0         A/5 21171   7.2500    NaN        S
# 1              1           0          PC 17599  71.2833    C85        C
# 2              0           0  STON/O2. 3101282   7.9250    NaN        S
# 3              1           0            113803  53.1000   C123        S
# 4              0           0            373450   8.0500    NaN        S

# %%
data['sexo'].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sexo, dtype: object

# %%
data['sexo'].replace({'male': 'homem', 'female': 'mulher'}, inplace=True)

# %%
#for idx, _ in data[['cabine']].dropna().iterrows():
#    data['cabine'].at[idx] = data['cabine'].at[idx][0]
data['cabine'] = data['cabine'].apply(lambda x: x[0] if pd.notna(x) else np.nan)

# %%
data['cabine']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
# 5      NaN
# 6        E
# 7      NaN
# 8      NaN
# 9      NaN
# 10       G
# 11       C
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21       D
# 22     NaN
# 23       A
# 24     NaN
# 25     NaN
# 26     NaN
# 27       C
# 28     NaN
# 29     NaN
#       ...
# 861    NaN
# 862      D
# 863    NaN
# 864    NaN
# 865    NaN
# 866    NaN
# 867      A
# 868    NaN
# 869    NaN
# 870    NaN
# 871      D
# 872      B
# 873    NaN
# 874    NaN
# 875    NaN
# 876    NaN
# 877    NaN
# 878    NaN
# 879      C
# 880    NaN
# 881    NaN
# 882    NaN
# 883    NaN
# 884    NaN
# 885    NaN
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: cabine, Length: 891, dtype: object

# %% [markdown]
# <h1> Matplotlib

# %%
data[['idade']]
# Out:
#      idade
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# 20    35.0
# 21    34.0
# 22    15.0
# 23    28.0
# 24     8.0
# 25    38.0
# 26     NaN
# 27    19.0
# 28     NaN
# 29     NaN
# ..     ...
# 861   21.0
# 862   48.0
# 863    NaN
# 864   24.0
# 865   42.0
# 866   27.0
# 867   31.0
# 868    NaN
# 869    4.0
# 870   26.0
# 871   47.0
# 872   33.0
# 873   47.0
# 874   28.0
# 875   15.0
# 876   20.0
# 877   19.0
# 878    NaN
# 879   56.0
# 880   25.0
# 881   33.0
# 882   22.0
# 883   28.0
# 884   25.0
# 885   39.0
# 886   27.0
# 887   19.0
# 888    NaN
# 889   26.0
# 890   32.0
#
# [891 rows x 1 columns]

# %%
data['idade'].isnull().sum()
# Out:
# 177

# %%
plt.hist(data['idade'].dropna(), bins=20)
plt.title('Distribuição por idade')
plt.xlabel('Idade')
plt.ylabel('Pessoas')
plt.show()

# %%
data['classe'].unique()
# Out:
# array([3, 1, 2])

# %%
plt.hist(data['classe'], bins=5)
plt.title('Distribuição por Classe')
plt.xlabel('Classe')
plt.ylabel('Pessoas')
plt.xticks(np.arange(5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da21f85184fe> in <module>
# ----> 1 plt.hist(data['classe'], bins=5)
#       2 plt.title('Distribuição por Classe')
#       3 plt.xlabel('Classe')
#       4 plt.ylabel('Pessoas')
#       5 plt.xticks(np.arange(5))
#
# NameError: name 'plt' is not defined
